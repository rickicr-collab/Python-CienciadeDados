# %%
'''implementar em python uma solução para estudar comportamento de uma serie temporal com regressão linear'''
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

x = np.array([5, 10, 15, 20, 25, 30]).reshape((-1, 1))
y = np.array([6, 12, 14, 23, 27, 32])

model = LinearRegression().fit(x, y)

y_pred = model.predict(x)
print('Dados do teste:', y, sep = '\n')
print('Dados de predição:', y_pred, sep = '\n')

plt.scatter(x, y, c = 'blue')
plt.plot(x, y_pred, c = 'red')
plt.legend('Predição', 'Real')
plt.show()
# Out:
# Dados do teste:
# [ 6 12 14 23 27 32]
# Dados de predição:
# [ 5.85714286 11.11428571 16.37142857 21.62857143 26.88571429 32.14285714]
# C:\Users\Ricardo\AppData\Local\Temp\ipykernel_11564\4184950330.py:17: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#controlling-the-legend-entries
#   plt.legend('Predição', 'Real')
